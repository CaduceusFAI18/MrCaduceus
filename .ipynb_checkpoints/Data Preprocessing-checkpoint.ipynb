# %%
import pandas as pd
from os import listdir

# %%
#TODO
#Part 1
#Load in Kaggle Data
#Merge Kaggle Dataframes by ID
#Add empty bool columns for each disease name
#If variable returns true, add true to disease name column
#export table with IDs, boolDisease

#Write a script to read raw data, merge it by ID, and spit out a CSV

# %%
# Load Kaggle data
df = []
for file in listdir("data/2014-kaggle/"):
    filename = "data/2014-kaggle/" + file
    print("Reading %s " % filename)
    df.append(pd.read_csv(filename))
# Out:
# Reading data/2014-kaggle/medications.csv
# Reading data/2014-kaggle/diet.csv
# Reading data/2014-kaggle/examination.csv
# Reading data/2014-kaggle/demographic.csv
# Reading data/2014-kaggle/labs.csv
# Reading data/2014-kaggle/questionnaire.csv

# %%
#Merge Kaggle dataframes by ID
from functools import reduce
df_final = reduce(lambda left,right: pd.merge(left,right,on='SEQN'), df[1:5])

# %%
''' 
# Check for duplicates in the dataframes
for i in range(5):
    print(df[i]['SEQN'].isin(df[i]['SEQN'].value_counts()[df[i]['SEQN'].value_counts()>2].index).value_counts())
'''
# Out:
# True     11305
# False     8889
# Name: SEQN, dtype: int64
# False    9813
# Name: SEQN, dtype: int64
# False    9813
# Name: SEQN, dtype: int64
# False    10175
# Name: SEQN, dtype: int64
# False    9813
# Name: SEQN, dtype: int64

# %%
df_final.columns.values
# Out:
# array(['SEQN', 'WTDRD1', 'WTDR2D', 'DR1DRSTZ', 'DR1EXMER', 'DRABF',
#        'DRDINT', 'DR1DBIH', 'DR1DAY', 'DR1LANG', 'DR1MNRSP', 'DR1HELPD',
#        'DBQ095Z', 'DBD100', 'DRQSPREP', 'DR1STY', 'DR1SKY', 'DRQSDIET',
#        'DRQSDT1', 'DRQSDT2', 'DRQSDT3', 'DRQSDT4', 'DRQSDT5', 'DRQSDT6',
#        'DRQSDT7', 'DRQSDT8', 'DRQSDT9', 'DRQSDT10', 'DRQSDT11',
#        'DRQSDT12', 'DRQSDT91', 'DR1TNUMF', 'DR1TKCAL', 'DR1TPROT',
#        'DR1TCARB', 'DR1TSUGR', 'DR1TFIBE', 'DR1TTFAT', 'DR1TSFAT',
#        'DR1TMFAT', 'DR1TPFAT', 'DR1TCHOL', 'DR1TATOC', 'DR1TATOA',
#        'DR1TRET', 'DR1TVARA', 'DR1TACAR', 'DR1TBCAR', 'DR1TCRYP',
#        'DR1TLYCO', 'DR1TLZ', 'DR1TVB1', 'DR1TVB2', 'DR1TNIAC', 'DR1TVB6',
#        'DR1TFOLA', 'DR1TFA', 'DR1TFF', 'DR1TFDFE', 'DR1TCHL', 'DR1TVB12',
#        'DR1TB12A', 'DR1TVC', 'DR1TVD', 'DR1TVK', 'DR1TCALC', 'DR1TPHOS',
#        'DR1TMAGN', 'DR1TIRON', 'DR1TZINC', 'DR1TCOPP', 'DR1TSODI',
#        'DR1TPOTA', 'DR1TSELE', 'DR1TCAFF', 'DR1TTHEO', 'DR1TALCO',
#        'DR1TMOIS', 'DR1TS040', 'DR1TS060', 'DR1TS080', 'DR1TS100',
#        'DR1TS120', 'DR1TS140', 'DR1TS160', 'DR1TS180', 'DR1TM161',
#        'DR1TM181', 'DR1TM201', 'DR1TM221', 'DR1TP182', 'DR1TP183',
#        'DR1TP184', 'DR1TP204', 'DR1TP205', 'DR1TP225', 'DR1TP226',
#        'DR1.300', 'DR1.320Z', 'DR1.330Z', 'DR1BWATZ', 'DR1TWS', 'DRD340',
#        'DRD350A', 'DRD350AQ', 'DRD350B', 'DRD350BQ', 'DRD350C',
#        'DRD350CQ', 'DRD350D', 'DRD350DQ', 'DRD350E', 'DRD350EQ',
#        'DRD350F', 'DRD350FQ', 'DRD350G', 'DRD350GQ', 'DRD350H',
#        'DRD350HQ', 'DRD350I', 'DRD350IQ', 'DRD350J', 'DRD350JQ',
#        'DRD350K', 'DRD360', 'DRD370A', 'DRD370AQ', 'DRD370B', 'DRD370BQ',
#        'DRD370C', 'DRD370CQ', 'DRD370D', 'DRD370DQ', 'DRD370E',
#        'DRD370EQ', 'DRD370F', 'DRD370FQ', 'DRD370G', 'DRD370GQ',
#        'DRD370H', 'DRD370HQ', 'DRD370I', 'DRD370IQ', 'DRD370J',
#        'DRD370JQ', 'DRD370K', 'DRD370KQ', 'DRD370L', 'DRD370LQ',
#        'DRD370M', 'DRD370MQ', 'DRD370N', 'DRD370NQ', 'DRD370O',
#        'DRD370OQ', 'DRD370P', 'DRD370PQ', 'DRD370Q', 'DRD370QQ',
#        'DRD370R', 'DRD370RQ', 'DRD370S', 'DRD370SQ', 'DRD370T',
#        'DRD370TQ', 'DRD370U', 'DRD370UQ', 'DRD370V', 'PEASCST1',
#        'PEASCTM1', 'PEASCCT1', 'BPXCHR', 'BPAARM', 'BPACSZ', 'BPXPLS',
#        'BPXPULS', 'BPXPTY', 'BPXML1', 'BPXSY1', 'BPXDI1', 'BPAEN1',
#        'BPXSY2', 'BPXDI2', 'BPAEN2', 'BPXSY3', 'BPXDI3', 'BPAEN3',
#        'BPXSY4', 'BPXDI4', 'BPAEN4', 'BMDSTATS', 'BMXWT', 'BMIWT',
#        'BMXRECUM', 'BMIRECUM', 'BMXHEAD', 'BMIHEAD', 'BMXHT', 'BMIHT',
#        'BMXBMI', 'BMDBMIC', 'BMXLEG', 'BMILEG', 'BMXARML', 'BMIARML',
#        'BMXARMC', 'BMIARMC', 'BMXWAIST', 'BMIWAIST', 'BMXSAD1', 'BMXSAD2',
#        'BMXSAD3', 'BMXSAD4', 'BMDAVSAD', 'BMDSADCM', 'MGDEXSTS', 'MGD050',
#        'MGD060', 'MGQ070', 'MGQ080', 'MGQ090', 'MGQ100', 'MGQ110',
#        'MGQ120', 'MGD130', 'MGQ90DG', 'MGDSEAT', 'MGAPHAND', 'MGATHAND',
#        'MGXH1T1', 'MGXH1T1E', 'MGXH2T1', 'MGXH2T1E', 'MGXH1T2',
#        'MGXH1T2E', 'MGXH2T2', 'MGXH2T2E', 'MGXH1T3', 'MGXH1T3E',
#        'MGXH2T3', 'MGXH2T3E', 'MGDCGSZ', 'OHDEXSTS', 'OHDDESTS', 'OHXIMP',
#        'OHX01TC', 'OHX02TC', 'OHX03TC', 'OHX04TC', 'OHX05TC', 'OHX06TC',
#        'OHX07TC', 'OHX08TC', 'OHX09TC', 'OHX10TC', 'OHX11TC', 'OHX12TC',
#        'OHX13TC', 'OHX14TC', 'OHX15TC', 'OHX16TC', 'OHX17TC', 'OHX18TC',
#        'OHX19TC', 'OHX20TC', 'OHX21TC', 'OHX22TC', 'OHX23TC', 'OHX24TC',
#        'OHX25TC', 'OHX26TC', 'OHX27TC', 'OHX28TC', 'OHX29TC', 'OHX30TC',
#        'OHX31TC', 'OHX32TC', 'OHX02CTC', 'OHX03CTC', 'OHX04CTC',
#        'OHX05CTC', 'OHX06CTC', 'OHX07CTC', 'OHX08CTC', 'OHX09CTC',
#        'OHX10CTC', 'OHX11CTC', 'OHX12CTC', 'OHX13CTC', 'OHX14CTC',
#        'OHX15CTC', 'OHX18CTC', 'OHX19CTC', 'OHX20CTC', 'OHX21CTC',
#        'OHX22CTC', 'OHX23CTC', 'OHX24CTC', 'OHX25CTC', 'OHX26CTC',
#        'OHX27CTC', 'OHX28CTC', 'OHX29CTC', 'OHX30CTC', 'OHX31CTC',
#        'OHX02CSC', 'OHX03CSC', 'OHX04CSC', 'OHX05CSC', 'OHX06CSC',
#        'OHX07CSC', 'OHX08CSC', 'OHX09CSC', 'OHX10CSC', 'OHX11CSC',
#        'OHX12CSC', 'OHX13CSC', 'OHX14CSC', 'OHX15CSC', 'OHX18CSC',
#        'OHX19CSC', 'OHX20CSC', 'OHX21CSC', 'OHX22CSC', 'OHX23CSC',
#        'OHX24CSC', 'OHX25CSC', 'OHX26CSC', 'OHX27CSC', 'OHX28CSC',
#        'OHX29CSC', 'OHX30CSC', 'OHX31CSC', 'OHX02SE', 'OHX03SE',
#        'OHX04SE', 'OHX05SE', 'OHX07SE', 'OHX10SE', 'OHX12SE', 'OHX13SE',
#        'OHX14SE', 'OHX15SE', 'OHX18SE', 'OHX19SE', 'OHX20SE', 'OHX21SE',
#        'OHX28SE', 'OHX29SE', 'OHX30SE', 'OHX31SE', 'CSXEXSTS', 'CSXEXCMT',
#        'CSQ245', 'CSQ241', 'CSQ260A', 'CSQ260D', 'CSQ260G', 'CSQ260I',
#        'CSQ260N', 'CSQ260M', 'CSQ270', 'CSQ450', 'CSQ460', 'CSQ470',
#        'CSQ480', 'CSQ490', 'CSXQUIPG', 'CSXQUIPT', 'CSXNAPG', 'CSXNAPT',
#        'CSXQUISG', 'CSXQUIST', 'CSXSLTSG', 'CSXSLTST', 'CSXNASG',
#        'CSXNAST', 'CSXTSEQ', 'CSXCHOOD', 'CSXSBOD', 'CSXSMKOD',
#        'CSXLEAOD', 'CSXSOAOD', 'CSXGRAOD', 'CSXONOD', 'CSXNGSOD',
#        'CSXSLTRT', 'CSXSLTRG', 'CSXNART', 'CSXNARG', 'CSAEFFRT',
#        'SDDSRVYR', 'RIDSTATR', 'RIAGENDR', 'RIDAGEYR', 'RIDAGEMN',
#        'RIDRETH1', 'RIDRETH3', 'RIDEXMON', 'RIDEXAGM', 'DMQMILIZ',
#        'DMQADFC', 'DMDBORN4', 'DMDCITZN', 'DMDYRSUS', 'DMDEDUC3',
#        'DMDEDUC2', 'DMDMARTL', 'RIDEXPRG', 'SIALANG', 'SIAPROXY',
#        'SIAINTRP', 'FIALANG', 'FIAPROXY', 'FIAINTRP', 'MIALANG',
#        'MIAPROXY', 'MIAINTRP', 'AIALANGA', 'DMDHHSIZ', 'DMDFMSIZ',
#        'DMDHHSZA', 'DMDHHSZB', 'DMDHHSZE', 'DMDHRGND', 'DMDHRAGE',
#        'DMDHRBR4', 'DMDHREDU', 'DMDHRMAR', 'DMDHSEDU', 'WTINT2YR',
#        'WTMEC2YR', 'SDMVPSU', 'SDMVSTRA', 'INDHHIN2', 'INDFMIN2',
#        'INDFMPIR', 'URXUMA', 'URXUMS', 'URXUCR.x', 'URXCRS', 'URDACT',
#        'WTSAF2YR.x', 'LBXAPB', 'LBDAPBSI', 'LBXSAL', 'LBDSALSI',
#        'LBXSAPSI', 'LBXSASSI', 'LBXSATSI', 'LBXSBU', 'LBDSBUSI',
#        'LBXSC3SI', 'LBXSCA', 'LBDSCASI', 'LBXSCH', 'LBDSCHSI', 'LBXSCK',
#        'LBXSCLSI', 'LBXSCR', 'LBDSCRSI', 'LBXSGB', 'LBDSGBSI', 'LBXSGL',
#        'LBDSGLSI', 'LBXSGTSI', 'LBXSIR', 'LBDSIRSI', 'LBXSKSI',
#        'LBXSLDSI', 'LBXSNASI', 'LBXSOSSI', 'LBXSPH', 'LBDSPHSI', 'LBXSTB',
#        'LBDSTBSI', 'LBXSTP', 'LBDSTPSI', 'LBXSTR', 'LBDSTRSI', 'LBXSUA',
#        'LBDSUASI', 'LBXWBCSI', 'LBXLYPCT', 'LBXMOPCT', 'LBXNEPCT',
#        'LBXEOPCT', 'LBXBAPCT', 'LBDLYMNO', 'LBDMONO', 'LBDNENO',
#        'LBDEONO', 'LBDBANO', 'LBXRBCSI', 'LBXHGB', 'LBXHCT', 'LBXMCVSI',
#        'LBXMCHSI', 'LBXMC', 'LBXRDW', 'LBXPLTSI', 'LBXMPSI', 'URXUCL',
#        'WTSA2YR.x', 'LBXSCU', 'LBDSCUSI', 'LBXSSE', 'LBDSSESI', 'LBXSZN',
#        'LBDSZNSI', 'URXUCR.y', 'WTSB2YR.x', 'URXBP3', 'URDBP3LC',
#        'URXBPH', 'URDBPHLC', 'URXBPF', 'URDBPFLC', 'URXBPS', 'URDBPSLC',
#        'URXTLC', 'URDTLCLC', 'URXTRS', 'URDTRSLC', 'URXBUP', 'URDBUPLC',
#        'URXEPB', 'URDEPBLC', 'URXMPB', 'URDMPBLC', 'URXPPB', 'URDPPBLC',
#        'URX14D', 'URD14DLC', 'URXDCB', 'URDDCBLC', 'URXUCR', 'PHQ020',
#        'PHACOFHR', 'PHACOFMN', 'PHQ030', 'PHAALCHR', 'PHAALCMN', 'PHQ040',
#        'PHAGUMHR', 'PHAGUMMN', 'PHQ050', 'PHAANTHR', 'PHAANTMN', 'PHQ060',
#        'PHASUPHR', 'PHASUPMN', 'PHAFSTHR.x', 'PHAFSTMN.x', 'PHDSESN',
#        'LBDPFL', 'LBDWFL', 'LBDHDD', 'LBDHDDSI', 'LBXHA', 'LBXHBS',
#        'LBXHBC', 'LBDHBG', 'LBDHD', 'LBXHCR', 'LBXHCG', 'LBDHEG',
#        'LBDHEM', 'LBXHE1', 'LBXHE2', 'LBXGH', 'LBDHI', 'ORXGH', 'ORXGL',
#        'ORXH06', 'ORXH11', 'ORXH16', 'ORXH18', 'ORXH26', 'ORXH31',
#        'ORXH33', 'ORXH35', 'ORXH39', 'ORXH40', 'ORXH42', 'ORXH45',
#        'ORXH51', 'ORXH52', 'ORXH53', 'ORXH54', 'ORXH55', 'ORXH56',
#        'ORXH58', 'ORXH59', 'ORXH61', 'ORXH62', 'ORXH64', 'ORXH66',
#        'ORXH67', 'ORXH68', 'ORXH69', 'ORXH70', 'ORXH71', 'ORXH72',
#        'ORXH73', 'ORXH81', 'ORXH82', 'ORXH83', 'ORXH84', 'ORXHPC',
#        'ORXHPI', 'ORXHPV', 'LBDRPCR.x', 'LBDRHP.x', 'LBDRLP.x',
#        'LBDR06.x', 'LBDR11.x', 'LBDR16.x', 'LBDR18.x', 'LBDR26.x',
#        'LBDR31.x', 'LBDR33.x', 'LBDR35.x', 'LBDR39.x', 'LBDR40.x',
#        'LBDR42.x', 'LBDR45.x', 'LBDR51.x', 'LBDR52.x', 'LBDR53.x',
#        'LBDR54.x', 'LBDR55.x', 'LBDR56.x', 'LBDR58.x', 'LBDR59.x',
#        'LBDR61.x', 'LBDR62.x', 'LBDR64.x', 'LBDR66.x', 'LBDR67.x',
#        'LBDR68.x', 'LBDR69.x', 'LBDR70.x', 'LBDR71.x', 'LBDR72.x',
#        'LBDR73.x', 'LBDR81.x', 'LBDR82.x', 'LBDR83.x', 'LBDR84.x',
#        'LBDR89.x', 'LBDRPI.x', 'LBXHP2C', 'LBDRPCR.y', 'LBDRHP.y',
#        'LBDRLP.y', 'LBDR06.y', 'LBDR11.y', 'LBDR16.y', 'LBDR18.y',
#        'LBDR26.y', 'LBDR31.y', 'LBDR33.y', 'LBDR35.y', 'LBDR39.y',
#        'LBDR40.y', 'LBDR42.y', 'LBDR45.y', 'LBDR51.y', 'LBDR52.y',
#        'LBDR53.y', 'LBDR54.y', 'LBDR55.y', 'LBDR56.y', 'LBDR58.y',
#        'LBDR59.y', 'LBDR61.y', 'LBDR62.y', 'LBDR64.y', 'LBDR66.y',
#        'LBDR67.y', 'LBDR68.y', 'LBDR69.y', 'LBDR70.y', 'LBDR71.y',
#        'LBDR72.y', 'LBDR73.y', 'LBDR81.y', 'LBDR82.y', 'LBDR83.y',
#        'LBDR84.y', 'LBDR89.y', 'LBDRPI.y', 'WTSAF2YR.y', 'LBXIN',
#        'LBDINSI', 'PHAFSTHR.y', 'PHAFSTMN.y', 'URXUIO', 'WTSAF2YR',
#        'LBXTR', 'LBDTRSI', 'LBDLDL', 'LBDLDLSI', 'WTSH2YR.x', 'LBXIHG',
#        'LBDIHGSI', 'LBDIHGLC', 'LBXBGE', 'LBDBGELC', 'LBXBGM', 'LBDBGMLC',
#        'WTSOG2YR', 'LBXGLT', 'LBDGLTSI', 'GTDSCMMN', 'GTDDR1MN',
#        'GTDBL2MN', 'GTDDR2MN', 'GTXDRANK', 'PHAFSTHR', 'PHAFSTMN',
#        'GTDCODE', 'WTSA2YR.y', 'URXP01', 'URDP01LC', 'URXP02', 'URDP02LC',
#        'URXP03', 'URDP03LC', 'URXP04', 'URDP04LC', 'URXP06', 'URDP06LC',
#        'URXP10', 'URDP10LC', 'URXP25', 'URDP25LC', 'WTSA2YR', 'URXUP8',
#        'URDUP8LC', 'URXNO3', 'URDNO3LC', 'URXSCN', 'URDSCNLC',
#        'WTSB2YR.y', 'LBXPFDE', 'LBDPFDEL', 'LBXPFHS', 'LBDPFHSL',
#        'LBXMPAH', 'LBDMPAHL', 'LBXPFBS', 'LBDPFBSL', 'LBXPFHP',
#        'LBDPFHPL', 'LBXPFNA', 'LBDPFNAL', 'LBXPFUA', 'LBDPFUAL',
#        'LBXPFDO', 'LBDPFDOL', 'WTSB2YR', 'URXCNP', 'URDCNPLC', 'URXCOP',
#        'URDCOPLC', 'URXECP', 'URDECPLC', 'URXMBP', 'URDMBPLC', 'URXMC1',
#        'URDMC1LC', 'URXMEP', 'URDMEPLC', 'URXMHH', 'URDMHHLC', 'URXMHNC',
#        'URDMCHLC', 'URXMHP', 'URDMHPLC', 'URXMIB', 'URDMIBLC', 'URXMNP',
#        'URDMNPLC', 'URXMOH', 'URDMOHLC', 'URXMZP', 'URDMZPLC', 'LBXTC',
#        'LBDTCSI', 'LBXTTG', 'LBXEMA', 'WTSH2YR.y', 'LBXBPB', 'LBDBPBSI',
#        'LBDBPBLC', 'LBXBCD', 'LBDBCDSI', 'LBDBCDLC', 'LBXTHG', 'LBDTHGSI',
#        'LBDTHGLC', 'LBXBSE', 'LBDBSESI', 'LBDBSELC', 'LBXBMN', 'LBDBMNSI',
#        'LBDBMNLC', 'URXUTRI', 'URXUAS3', 'URDUA3LC', 'URXUAS5',
#        'URDUA5LC', 'URXUAB', 'URDUABLC', 'URXUAC', 'URDUACLC', 'URXUDMA',
#        'URDUDALC', 'URXUMMA', 'URDUMMAL', 'URXVOL1', 'URDFLOW1',
#        'URXVOL2', 'URDFLOW2', 'URXVOL3', 'URDFLOW3', 'URXUHG', 'URDUHGLC',
#        'URXUBA', 'URDUBALC', 'URXUCD', 'URDUCDLC', 'URXUCO', 'URDUCOLC',
#        'URXUCS', 'URDUCSLC', 'URXUMO', 'URDUMOLC', 'URXUMN', 'URDUMNLC',
#        'URXUPB', 'URDUPBLC', 'URXUSB', 'URDUSBLC', 'URXUSN', 'URDUSNLC',
#        'URXUSR', 'URDUSRLC', 'URXUTL', 'URDUTLLC', 'URXUTU', 'URDUTULC',
#        'URXUUR', 'URDUURLC', 'URXPREG', 'URXUAS', 'LBDB12', 'LBDB12SI'],
#       dtype=object)

# %%
df_disease = pd.read_csv("data/DiseaseIndicators.csv")

# %%
df_disease_filt = df_disease[df_disease['DiseaseName_char'].isna() != True]

# %%
for i in set(df_disease_filt['Variable Name']):
    print(i)
# Out:
# MCQ240z
# MCQ180f
# SXQ270
# DIQ010
# MCQ170k
# PFQ061O
# OSD030be
# OSQ120h
# OSD030bd
# MCQ160g
# OSQ120f
# OSQ080
# MCQ075
# MCQ230a
# OHAROTH
# MCQ240d
# MCQ180m
# PFQ061D
# PFQ061B
# DLQ010
# DLQ040
# PFQ057
# MCQ240dd
# MCQ053
# PFQ061E
# MCQ240dk
# MCQ180c
# PFQ061S
# CSQ241
# SXQ265
# PFQ061N
# OSD030bg
# MCQ203
# OSD030ba
# MCQ160k
# MCQ084
# MCQ230d
# MCQ195
# PFQ061T
# HEQ030
# OSQ120e
# MCQ240x
# DID260
# SXQ753
# MCQ240aa
# OSQ010b
# OSQ120a
# MCQ240i
# MCQ160c
# BPQ080
# CSQ220
# BPQ100D
# MCQ092
# BPQ090D
# MCQ240g
# BPQ020
# PFQ061G
# MCQ160a
# MCQ240k
# OHAROCOH
# MCQ240bb
# DID341
# OHAROCDT
# MCQ240m
# OSD030aa
# MCQ180b
# MGQ110
# MCQ240a
# MCQ240q
# AGQ030
# MCQ240v
# OSQ060
# MCQ240n
# SXQ272
# MGD050
# MCQ160b
# MCQ240t
# MCQ170m
# PFQ061R
# OHAROCDE
# MCQ160e
# DLQ080
# PFQ061J
# DIQ080
# MCQ180d
# BPQ050A
# PFQ054
# MCQ240l
# PFQ051
# BPQ030
# CSQ250
# OSQ010c
# MCQ180k
# MCQ160f
# MCQ240o
# MCQ240y
# MCQ240u
# PFQ061L
# PFQ061C
# MCQ025
# MCQ240h
# OHAREC
# MCQ380
# MCQ206
# OSD030ab
# MCQ180g
# MCQ160o
# OHAROCCI
# OSQ072
# MCQ240w
# MCQ050
# PFQ061H
# MCQ160n
# DIQ050
# MCQ082
# MCQ080
# MCQ240s
# DLQ020
# OSD030bb
# MCQ070
# OSQ120c
# OSQ120b
# DID040
# MCQ035
# MCQ040
# MCQ160d
# CSQ240
# CSQ260
# PFQ061I
# DID060
# PFQ061A
# BPD035
# PFQ061Q
# MCQ180l
# OSQ120g
# HEQ010
# MCQ080E
# MCQ240p
# MCQ170l
# MCQ240cc
# MCQ010
# MCQ230b
# MCQ220
# MCQ240r
# MGQ080
# BPQ040A
# PFQ061M
# MCQ240f
# MCQ160m
# PFQ061K
# PFQ059
# MCQ230c
# MCQ240j
# OSD030bc
# MCQ180a
# OSD030bf
# OSQ010a
# PFQ061P
# MCQ160l
# OSD030ac
# MCD093
# PFQ061F
# MCQ180n
# OSQ120d
# MCQ240e
# SXQ260
# MCQ180e
# MCQ240c
# MCQ240b
# OHAROCGP

# %%
def response_type_select(response, val):
    if response == 1:
        response_1(val)
    if response == 2:
        response_2(val)
    if response == 3:
        response_3(val)
    if response == 4:
        response_4(val)
    if response == 5:
        response_4(val)
    if response == 6:
        response_6(val)
    if response == 7:
        response_7(val)
    if response == 8:
        response_8(val)
    if response == 9:
        response_9(val)
    if response == 10:
        response_10(val)
    if response == 11:
        response_11(val)
    if response == 12:
        response_12(val)
    if response == 13:
        response_13(val)
    if response == 14:
        response_14(val)
    if response == 15:
        response_15(val)
    else:
        print("No matching response type")
        return(False)

# %%
def response_1(val):
    if val == 1:
        return("Yes")
    if val == 2:
        return("No")
    if val == 7:
        return("Refused")
    if val == 9:
        return("Don't Know")
    if math.isnan(val):
        return("No")
    else:
        return(float('nan'))

# %%
def response_2(val):
    if val == 777:
        return("Refused")
    if val == 999:
        return("Don't Know")
    if math.isnan(val):
        return("No")
    else:
        return(val)

# %%
def response_3(val):
    if val == 666:
        return(1)
    if val == 777:
        return("Refused")
    if val == 999:
        return("Don't Know")
    if math.isnan(val):
        return("No")
    else:
        return(val)

# %%
def response_4(val):
    if val == 0:
        return("No")
    if val == 777:
        return("Refused")
    if val == 999:
        return("Don't Know")
    if math.isnan(val):
        return("No")
    else:
        return(val)
# Out:
# True

# %%
def response_5(val):
    if val == 0:
        return("No")
    if val == 7777:
        return("Refused")
    if val == 9999:
        return("Don't Know")
    if math.isnan(val):
        return("No")
    else:
        return(val)

# %%
def response_6(val):
    if val == 1:
        return("Yes")
    if val == 2:
        return("No")
    if val == 3:
        return("Borderline")
    if val == 7:
        return("Refused")
    if val == 9:
        return("Don't Know")
    if math.isnan(val):
        return("No")

# %%
def response_7(val):
    if val == 1:
        return("Before 1972")
    if val == 2:
        return("1972-1991")
    if val == 3:
        return("1992 to Present")
    if val == 7:
        return("Refused")
    if val == 9:
        return("Don't Know")
    if math.isnan(val):
        return("No")

# %%
def response_8(val):
    if val == 77777:
        return("Refused")
    if val == 99999:
        return("Don't Know")
    if math.isnan(val):
        return("No")
    else:
        return(val)

# %%
def response_9(val):
    if val == 1:
        return("Little or None")
    if val == 2:
        return("Small amount")
    if val == 3:
        return("Medium amount")
    if val == 4:
        return("Large amount")
    if val == 7:
        return("Refused")
    if val == 9:
        return("Don't Know")
    if math.isnan(val):
        return("No")
    else:
        return(val)

# %%
def response_10(val):
    if val == 1:
        return("Osteoarthritis/degenerative")
    if val == 2:
        return("Rheumatoid")
    if val == 3:
        return("Psioratic")
    if val == 4:
        return("Other")
    if val == 7:
        return("Refused")
    if val == 9:
        return("Don't Know")
    if math.isnan(val):
        return("No")

# %%
def response_11(val):
    if val == 0:
        return("No")
    if val == 1:
        return("Once")
    if val == 2:
        return("Two-Three Times")
    if val == 3:
        return("Nearly Every day")
    if val == 4:
        return("Several Times a Day")
    if val == 7:
        return("Refused")
    if val == 9:
        return("Don't Know")
    if math.isnan(val):
        return("No")

# %%
def response_12(val):
    if val == 1:
        return("See dentist immediately")
    if val == 2:
        return("See dentist within two weeks")
    if val == 3:
        return("See dentist at earliest convenience")
    if val == 4:
        return("Continue routine care")
    if math.isnan(val):
        return("No")

# %%
def response_13(val):
    if val == 1:
        return("Yes")
    if val == 2:
        return("No")
    if math.isnan(val):
        return("No")

# %%
def response_14(val):
    if val == 1:
        return("No")
    if val == 2:
        return("Some difficulty")
    if val == 3:
        return("Much difficulty")
    if val == 4:
        return("Unable to do")
    if val == 5:
        return("No")
    if val == 7:
        return("Refused")
    if val == 9:
        return("Don't Know")
    if math.isnan(val):
        return("No")

# %%
def response_15(val):
    if val == 77:
        return("Refused")
    if val == 99:
        return("Don't Know")
    if math.isnan(val):
        return("No")
    else:
        return("Yes")

# %%
set(df_disease['DiseaseName_char'])
# Out:
# {'Anemia',
#  'Angina',
#  'Arthritis',
#  'Asthma',
#  'BladderCancer',
#  'Blindness',
#  'BloodCancer',
#  'BloodTransfusion',
#  'BoneCancer',
#  'BrainCancer',
#  'BreastCancer',
#  'BrokenFace',
#  'Cancer',
#  'Carpal_Tunnel_Arthritis',
#  'Celiac',
#  'CervicalCancer',
#  'Chlamydia',
#  'ChronicBronchitis',
#  'ChronicObstructivePulmonaryDisease',
#  'ColonCancer',
#  'Concussion',
#  'Deafness',
#  'Dental Care',
#  'Diabetes',
#  'Emphysema',
#  'EsophagealCancer',
#  'FootSores',
#  'FractureHip',
#  'FractureSpine',
#  'FractureWrist',
#  'FracturedBone',
#  'GallbladderCancer',
#  'GenericProblem',
#  'GenitalHerpes',
#  'GenitalWarts',
#  'Gonorrhea',
#  'Gout',
#  'HPV',
#  'HayFever',
#  'HeartAttack',
#  'HeartDisease',
#  'HeartFailure',
#  'HepatitisB',
#  'HepatitisC',
#  'HighCholesterol',
#  'HipFracture',
#  'Hypertension',
#  'Jaundice',
#  'KidneyCancer',
#  'LarynxCancer',
#  'LeukemiaCancer',
#  'LiverCancer',
#  'LiverCondition',
#  'LungCancer',
#  'Lymphoma',
#  'Melanoma',
#  'Memory',
#  'MentalDisorder',
#  'MentalHealth',
#  'MouthCancer',
#  'MovementDisorder',
#  'NervousSystemCancer',
#  'Osteoporosis',
#  'OtherCancer',
#  'OvarianCancer',
#  'Overweight',
#  'PancreaticCancer',
#  'Post-Natal Care',
#  'ProstateCancer',
#  'Psoriasis',
#  'RectalCancer',
#  'Retinopathy',
#  'SinusInfection',
#  'SkinCancerOther',
#  'StomachCancer',
#  'Stroke',
#  'TesticularCancer',
#  'ThyroidCancer',
#  'ThyroidCondition',
#  'TissueCancer',
#  'Tonsilitis',
#  'UterineCancer',
#  'WristFracture',
#  nan}

# %%
ACQ['SXQ270'].value_counts()
# Out:
# 2.0    3183
# 1.0      15
# 9.0       1
# Name: SXQ270, dtype: int64

# %%
df2 = pd.read_csv("data/DiseaseIndicators.csv")

# %%
df3 = pd.read_csv("data/DiseaseCostsV1.0.csv")

# %%
df3
# Out:
#            DiseaseName_char DiseaseCategory TreatmentCode    Cost  \
# 0                Tonsilitis          Throat          060N  1829.0
# 1                Concussion           Brain          901P   319.0
# 2                BrokenFace      BrokenBone          055P  1452.0
# 3            SinusInfection         Sinuses          7401   110.0
# 4                    Anemia     Circulatory          905P   428.0
# 5                    Angina     Circulatory          905P   428.0
# 6                 Arthritis           Joint          908O   776.0
# 7                    Asthma     Respiratory          7401   110.0
# 8                Bronchitis     Respiratory         "096"  2635.0
# 9             BladderCancer          Cancer           911  6120.0
# 10                Blindness             NaN          7801   393.0
# 11              BloodCancer          Cancer           917  3868.0
# 12         BloodTransfusion     Circulatory         WW500   123.0
# 13               BoneCancer          Cancer           491  6531.0
# 14              BrainCancer          Cancer         AAB00  4346.0
# 15             BreastCancer          Cancer           274  3952.0
# 16                   Cancer          Cancer          XXX1  4000.0
# 17  Carpal_Tunnel_Arthritis           Joint          006O   795.0
# 18                   Celiac      Autoimmune          710O   498.0
# 19           CervicalCancer          Cancer         LCD00  3529.0
# 20                Chlamydia             STD          7401   110.0
# 21        ChronicBronchitis     Respiratory         "088"  2590.0
# 22              ColonCancer          Cancer         JFH96  2712.0
# 23                 Deafness             NaN          7801   393.0
# 24              Dental Care             NaN           NaN     NaN
# 25                 Diabetes        Diabetes           NaN     NaN
# 26         EsophagealCancer          Cancer           NaN     NaN
# 27            FracturedBone    BoneFracture         NDJ42  1712.0
# 28             FracturedHip    BoneFracture         NEJ60  2772.0
# 29            FractureSpine    BoneFracture         NAJ32  6603.0
# ..                      ...             ...           ...     ...
# 47             KidneyCancer          Cancer         BCA30  2825.0
# 48             LarynxCancer          Cancer    DQB10ZXD30  2093.0
# 49           LeukemiaCancer          Cancer          404F  4096.0
# 50              LiverCancer          Cancer         JJA43  4781.0
# 51            LiverCondtion           Liver          907O   761.0
# 52               LungCancer          Cancer         GDA20  3476.0
# 53                 Lymphoma          Cancer          404F  4096.0
# 54                   Memory    MentalHealth           NaN     NaN
# 55                 Melanoma          Cancer         QDE10  1766.0
# 56           MentalDisorder       Cognitive           NaN     NaN
# 57              MouthCancer          Cancer    EJB10ZXC10  1598.0
# 58         MovementDisorder      Ambulatory           NaN     NaN
# 59      NervousSystemCancer          Cancer          011F  2282.0
# 60             Osteoporosis    Osteoporosis           NaN     NaN
# 61              OtherCancer          Cancer          XXX1  4000.0
# 62            OvarianCancer          Cancer         LAC00  2869.0
# 63               Overweight         Obesity         QBJ00  2266.0
# 64         PancreaticCancer          Cancer          192O  1467.0
# 65           ProstateCancer          Cancer           NaN     NaN
# 66                Psoriasis  Dermatological           NaN     NaN
# 67             RectalCancer          Cancer         JFH96  2712.0
# 68              Retinopathy          Vision          039P  1044.0
# 69          SkinCancerOther          Cancer         QDE10  1766.0
# 70            StomachCancer          Cancer         JDA63  2623.0
# 71                   Stroke     Circulatory          014A  4563.0
# 72         TesticularCancer          Cancer         KFC00  1415.0
# 73            ThyroidCancer          Cancer         BAA60  4004.0
# 74         ThyroidCondition         Thyroid           NaN     NaN
# 75             TissueCancer          Cancer          227O  1516.0
# 76            UterineCancer          Cancer         LCD00  3529.0
#
#                                                  info      Unnamed: 5
# 0                        Surgery (removal of tonsils)             NaN
# 1   Diagnosis of head, neck and central nervous sy...             NaN
# 2   Surgery on face (nose, mouth, ear or else, sho...             NaN
# 3          Ear, nose and throatdisease hospital visit             NaN
# 4   Heart- and circulation diagnostic procedure. (...             NaN
# 5       Heart- and circulation diagnostic procedure.              NaN
# 6   General Musculoskeletal disorder short treatme...             NaN
# 7   Basic hospital visit. Usually no special treat...             NaN
# 8   Obstructive respiratory complication (e.g. bec...             NaN
# 9   Average 20 * 169€ radiation therapy + 10 * 274...             NaN
# 10  Specialist consultation ( There might be no tr...             NaN
# 11           1432 Chemo + 14 * 174€ radiation therapy             NaN
# 12                                  Blood transfusion             NaN
# 13  Big upperbody prothesis surgery (Bone cancer i...             NaN
# 14                     Surgery to remove brain cancer             NaN
# 15                         Breast cancer, complicated             NaN
# 16      Something in the ballpark of cancertreatments             NaN
# 17                              Carpal tunnel surgery             NaN
# 18                                        Colonoscopy             NaN
# 19                                  Removal of Cervix             NaN
# 20                  basic hospital visit. Antibiotics             NaN
# 21                   Chronic obstructive lung disease             NaN
# 22  Other removal of colon. (cost depends on how m...             NaN
# 23       Specialist consultation same as in blindness             NaN
# 24                                                NaN             NaN
# 25            Just insulin and cholesterol medicine??  <- Yes - Keith
# 26                                                NaN             NaN
# 27  Repositioning and binding of bones in arm or h...             NaN
# 28                                 Hipfracture repair             NaN
# 29                  Lumbar vertebrae fracture surgery             NaN
# ..                                                ...             ...
# 47                                     Kidney removal             NaN
# 48                                            surgery             NaN
# 49                                                NaN             NaN
# 50              "Destruction of liver transformation"             NaN
# 51                        Treatment of liver disease              NaN
# 52                  Removal of transformaton in lungs             NaN
# 53                                                NaN             NaN
# 54                                                NaN             NaN
# 55           Removal of transformation in skin tissue             NaN
# 56                                                NaN             NaN
# 57                      Removal of cancer from tongue             NaN
# 58                                                NaN             NaN
# 59              Removal of cancer from nervous system             NaN
# 60                                                NaN             NaN
# 61                                   Cancer treatment             NaN
# 62                                 Removal of ovaries             NaN
# 63                                        Liposuction             NaN
# 64                                Surgery in pancreas             NaN
# 65                                                NaN             NaN
# 66            Dont think theres usually anything done             NaN
# 67                                                NaN             NaN
# 68                                        eye surgery             NaN
# 69           Removal of transformation in skin tissue             NaN
# 70               Removal of transformation in stomach             NaN
# 71  Cerebral infarction (technically not the same ...             NaN
# 72                                Removal of testicle             NaN
# 73                                 Removal of thyroid             NaN
# 74                                                NaN             NaN
# 75                                     Tissue surgery             NaN
# 76                                  Removal of Cervix             NaN
#
# [77 rows x 6 columns]

# %%
import sys
sys.setrecursionlimit(10000)

# %%
df3 = pd.read_csv("data/2014-kaggle/demographic.csv")

# %%
df_final[23:25]
# Out:
#      SEQN        WTDRD1        WTDR2D  DR1DRSTZ  DR1EXMER  DRABF  DRDINT  \
# 23  73582      0.000000           NaN         5       NaN    NaN     NaN
# 24  73583  38522.690763  29514.517908         1      49.0    2.0     2.0
#
#     DR1DBIH  DR1DAY  DR1LANG    ...     URXUTL  URDUTLLC  URXUTU  URDUTULC  \
# 23      NaN     NaN      NaN    ...        NaN       NaN     NaN       NaN
# 24     26.0     7.0      1.0    ...      0.461       0.0   0.148       0.0
#
#     URXUUR  URDUURLC  URXPREG  URXUAS  LBDB12  LBDB12SI
# 23     NaN       NaN      1.0     NaN     NaN       NaN
# 24  0.0178       0.0      NaN   24.09     NaN       NaN
#
# [2 rows x 860 columns]

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
counts = 0
for i in set(df2['Variable Name']):
    if i in set(df3)

# %%
question_id_and_disease = pd.read_csv("data/DiseaseIndicators.csv")

# %%
costs = pd.read_csv("data/DiseaseCostsV1.0.csv")
merged = question_id_and_disease.merge(costs, on="DiseaseName_char")
merged = merged.drop(merged.columns[6], axis=1)
merged = merged.dropna(subset = ["Cost"])

# %%
merged
# Out:
#     Variable Name                               Variable Description  \
# 0          MGD050  Have you ever had surgery on your hands or wri...
# 1          MGQ080  Is the pain, aching or stiffness in your right...
# 2          MGQ110  Is the pain, aching or stiffness in your left ...
# 10         DLQ010  With this next set of questions, we want to le...
# 11         DLQ020  {Are you/Is SP} blind or {do you/does he/does ...
# 12        OSQ010b  Has a doctor ever told {you/SP} that {you/s/he...
# 13        OSQ010c  Has a doctor ever told {you/SP} that {you/s/he...
# 16         OSQ080  Has a doctor ever told {you/SP} that {you/s/he...
# 17        OSQ120a  Has a doctor ever told {you/SP} that {you/s/he...
# 18        OSQ120b  Has a doctor ever told {you/SP} that {you/s/he...
# 19        OSQ120c  Has a doctor ever told {you/SP} that {you/s/he...
# 20        OSQ120d  Has a doctor ever told {you/SP} that {you/s/he...
# 21        OSQ120e  Has a doctor ever told {you/SP} that {you/s/he...
# 22        OSQ120f  Has a doctor ever told {you/SP} that {you/s/he...
# 23        OSQ120g  Has a doctor ever told {you/SP} that {you/s/he...
# 24        OSQ120h  Has a doctor ever told {you/SP} that {you/s/he...
# 25         SXQ260  Has a doctor or other health care professional...
# 26         SXQ265  Has a doctor or other health care professional...
# 27         SXQ270  In the past 12 months, has a doctor or other h...
# 28         SXQ272  In the past 12 months, has a doctor or other h...
# 29         SXQ753  Has a doctor or other health care professional...
# 30         BPD035  How old {were you/was SP} when {you were/he/sh...
# 31         BPQ020  {Have you/Has SP} ever been told by a doctor o...
# 32         BPQ030  {Were you/Was SP} told on 2 or more different ...
# 33        BPQ040A  Because of {your/SP's} (high blood pressure/hy...
# 34        BPQ050A  HELP AVAILABLE (Are you/Is SP) now taking pres...
# 35         BPQ080  {Have you/Has SP} ever been told by a doctor o...
# 36        BPQ090D  [To lower (your/his/her) blood cholesterol, (h...
# 37        BPQ100D  (Are you/Is SP) now following this advice to t...
# 38         AGQ030  During the past 12 months, {have you/has SP} h...
# ..            ...                                                ...
# 87        MCQ240d  How old (were you/was SP) when brain cancer wa...
# 88       MCQ240dd  How old (were you/was SP) when some other type...
# 89       MCQ240dk  How old {were you/was SP} when cancer was firs...
# 90        MCQ240e  How old (were you/was SP) when breast cancer w...
# 91        MCQ240f  How old (were you/was SP) when cervical cancer...
# 92        MCQ240g  How old (were you/was SP) when colon cancer wa...
# 94        MCQ240i  How old (were you/was SP) when gallbladder can...
# 95        MCQ240j  How old (were you/was SP) when kidney cancer w...
# 96        MCQ240k  How old (were you/was SP) when larynx or windp...
# 97        MCQ240l  How old (were you/was SP) when leukemia was fi...
# 98        MCQ240m  How old (were you/was SP) when liver cancer wa...
# 99        MCQ240n  How old (were you/was SP) when lung cancer was...
# 100       MCQ240o  How old (were you/was SP) when lymphoma or Hod...
# 101       MCQ240p  How old (were you/was SP) when melanoma was fi...
# 102       MCQ240q  How old (were you/was SP) when mouth, tongue, ...
# 103       MCQ240r  How old (were you/was SP) when cancer of the n...
# 104       MCQ240s  How old (were you/was SP) when ovarian cancer ...
# 105       MCQ240t  How old (were you/was SP) when pancreatic canc...
# 107       MCQ240v  How old (were you/was SP) when rectal cancer w...
# 108       MCQ240w  How old (were you/was SP) when non-melanoma sk...
# 109       MCQ240x  How old (were you/was SP) when the unknown kin...
# 110       MCQ240y  How old (were you/was SP) when soft tissue (mu...
# 111       MCQ240z  How old (were you/was SP) when stomach cancer ...
# 134        HEQ010  Has a doctor or other health professional ever...
# 135        HEQ030  Has a doctor or other health professional ever...
# 141        DIQ080  Has a doctor ever told {you/SP} that diabetes ...
# 142        CSQ220  {Have you/Has SP} ever had any of the followin...
# 143        CSQ240  {Have you/Has SP} ever had any of the followin...
# 144        CSQ250  {Have you/Has SP} ever had any of the followin...
# 145        CSQ260  {Have you/Has SP} ever had any of the followin...
#
#     Data File Name         Data File Description  Begin Year  EndYear  \
# 0            MGX_H   Muscle Strength - Grip Test        2013     2014
# 1            MGX_H   Muscle Strength - Grip Test        2013     2014
# 2            MGX_H   Muscle Strength - Grip Test        2013     2014
# 10           DLQ_H                    Disability        2013     2014
# 11           DLQ_H                    Disability        2013     2014
# 12           OSQ_H                  Osteoporosis        2013     2014
# 13           OSQ_H                  Osteoporosis        2013     2014
# 16           OSQ_H                  Osteoporosis        2013     2014
# 17           OSQ_H                  Osteoporosis        2013     2014
# 18           OSQ_H                  Osteoporosis        2013     2014
# 19           OSQ_H                  Osteoporosis        2013     2014
# 20           OSQ_H                  Osteoporosis        2013     2014
# 21           OSQ_H                  Osteoporosis        2013     2014
# 22           OSQ_H                  Osteoporosis        2013     2014
# 23           OSQ_H                  Osteoporosis        2013     2014
# 24           OSQ_H                  Osteoporosis        2013     2014
# 25           SXQ_H               Sexual Behavior        2013     2014
# 26           SXQ_H               Sexual Behavior        2013     2014
# 27           SXQ_H               Sexual Behavior        2013     2014
# 28           SXQ_H               Sexual Behavior        2013     2014
# 29           SXQ_H               Sexual Behavior        2013     2014
# 30           BPQ_H  Blood Pressure & Cholesterol        2013     2014
# 31           BPQ_H  Blood Pressure & Cholesterol        2013     2014
# 32           BPQ_H  Blood Pressure & Cholesterol        2013     2014
# 33           BPQ_H  Blood Pressure & Cholesterol        2013     2014
# 34           BPQ_H  Blood Pressure & Cholesterol        2013     2014
# 35           BPQ_H  Blood Pressure & Cholesterol        2013     2014
# 36           BPQ_H  Blood Pressure & Cholesterol        2013     2014
# 37           BPQ_H  Blood Pressure & Cholesterol        2013     2014
# 38           MCQ_H            Medical Conditions        2013     2014
# ..             ...                           ...         ...      ...
# 87           MCQ_H            Medical Conditions        2013     2014
# 88           MCQ_H            Medical Conditions        2013     2014
# 89           MCQ_H            Medical Conditions        2013     2014
# 90           MCQ_H            Medical Conditions        2013     2014
# 91           MCQ_H            Medical Conditions        2013     2014
# 92           MCQ_H            Medical Conditions        2013     2014
# 94           MCQ_H            Medical Conditions        2013     2014
# 95           MCQ_H            Medical Conditions        2013     2014
# 96           MCQ_H            Medical Conditions        2013     2014
# 97           MCQ_H            Medical Conditions        2013     2014
# 98           MCQ_H            Medical Conditions        2013     2014
# 99           MCQ_H            Medical Conditions        2013     2014
# 100          MCQ_H            Medical Conditions        2013     2014
# 101          MCQ_H            Medical Conditions        2013     2014
# 102          MCQ_H            Medical Conditions        2013     2014
# 103          MCQ_H            Medical Conditions        2013     2014
# 104          MCQ_H            Medical Conditions        2013     2014
# 105          MCQ_H            Medical Conditions        2013     2014
# 107          MCQ_H            Medical Conditions        2013     2014
# 108          MCQ_H            Medical Conditions        2013     2014
# 109          MCQ_H            Medical Conditions        2013     2014
# 110          MCQ_H            Medical Conditions        2013     2014
# 111          MCQ_H            Medical Conditions        2013     2014
# 134          HEQ_H                     Hepatitis        2013     2014
# 135          HEQ_H                     Hepatitis        2013     2014
# 141          DIQ_H                      Diabetes        2013     2014
# 142          CSQ_H                 Taste & Smell        2013     2014
# 143          CSQ_H                 Taste & Smell        2013     2014
# 144          CSQ_H                 Taste & Smell        2013     2014
# 145          CSQ_H                 Taste & Smell        2013     2014
#
#     Use Constraints  Sensitive_cat  ConditionIndicator  \
# 0              None            NaN                 1.0
# 1              None            NaN                 1.0
# 2              None            NaN                 1.0
# 10             None            1.0                 1.0
# 11             None            1.0                 1.0
# 12             None            NaN                 1.0
# 13             None            NaN                 1.0
# 16             None            NaN                 1.0
# 17             None            NaN                 1.0
# 18             None            NaN                 1.0
# 19             None            NaN                 1.0
# 20             None            NaN                 1.0
# 21             None            NaN                 1.0
# 22             None            NaN                 1.0
# 23             None            NaN                 1.0
# 24             None            NaN                 1.0
# 25             None            NaN                 1.0
# 26             None            NaN                 1.0
# 27             None            NaN                 1.0
# 28             None            NaN                 1.0
# 29             None            NaN                 1.0
# 30             None            NaN                 1.0
# 31             None            NaN                 1.0
# 32             None            NaN                 1.0
# 33             None            NaN                 2.0
# 34             None            NaN                 2.0
# 35             None            NaN                 1.0
# 36             None            NaN                 2.0
# 37             None            NaN                 2.0
# 38             None            NaN                 1.0
# ..              ...            ...                 ...
# 87             None            NaN                 1.0
# 88             None            NaN                 1.0
# 89             None            NaN                 2.0
# 90             None            NaN                 1.0
# 91             None            NaN                 1.0
# 92             None            NaN                 1.0
# 94             None            NaN                 1.0
# 95             None            NaN                 1.0
# 96             None            NaN                 1.0
# 97             None            NaN                 1.0
# 98             None            NaN                 1.0
# 99             None            NaN                 1.0
# 100            None            NaN                 1.0
# 101            None            NaN                 1.0
# 102            None            NaN                 1.0
# 103            None            NaN                 1.0
# 104            None            NaN                 1.0
# 105            None            NaN                 1.0
# 107            None            NaN                 1.0
# 108            None            NaN                 1.0
# 109            None            NaN                 1.0
# 110            None            NaN                 1.0
# 111            None            NaN                 1.0
# 134            None            NaN                 1.0
# 135            None            NaN                 1.0
# 141            None            NaN                 1.0
# 142            None            NaN                 1.0
# 143            None            NaN                 1.0
# 144            None            NaN                 1.0
# 145            None            NaN                 1.0
#
#             DiseaseName_char     ...     Overnight_bool  DrugIndicator  \
# 0    Carpal_Tunnel_Arthritis     ...                NaN            NaN
# 1    Carpal_Tunnel_Arthritis     ...                NaN            NaN
# 2    Carpal_Tunnel_Arthritis     ...                NaN            NaN
# 10                  Deafness     ...                NaN            NaN
# 11                 Blindness     ...                NaN            NaN
# 12             FractureWrist     ...                NaN            NaN
# 13             FractureSpine     ...                NaN            NaN
# 16             FracturedBone     ...                NaN            NaN
# 17             FracturedBone     ...                NaN            NaN
# 18             FracturedBone     ...                NaN            NaN
# 19             FracturedBone     ...                NaN            NaN
# 20             FracturedBone     ...                NaN            NaN
# 21             FracturedBone     ...                NaN            NaN
# 22             FracturedBone     ...                NaN            NaN
# 23             FracturedBone     ...                NaN            NaN
# 24             FracturedBone     ...                NaN            NaN
# 25             GenitalHerpes     ...                NaN            NaN
# 26              GenitalWarts     ...                NaN            NaN
# 27                 Gonorrhea     ...                NaN            NaN
# 28                 Chlamydia     ...                NaN            NaN
# 29                       HPV     ...                NaN            NaN
# 30              Hypertension     ...                NaN            NaN
# 31              Hypertension     ...                NaN            NaN
# 32              Hypertension     ...                NaN            NaN
# 33              Hypertension     ...                NaN            NaN
# 34              Hypertension     ...                NaN              1
# 35           HighCholesterol     ...                NaN            NaN
# 36           HighCholesterol     ...                NaN            NaN
# 37           HighCholesterol     ...                NaN              1
# 38                  HayFever     ...                NaN            NaN
# ..                       ...     ...                ...            ...
# 87               BrainCancer     ...                NaN            NaN
# 88               OtherCancer     ...                NaN            NaN
# 89               OtherCancer     ...                NaN            NaN
# 90              BreastCancer     ...                NaN            NaN
# 91            CervicalCancer     ...                NaN            NaN
# 92               ColonCancer     ...                NaN            NaN
# 94         GallbladderCancer     ...                NaN            NaN
# 95              KidneyCancer     ...                NaN            NaN
# 96              LarynxCancer     ...                NaN            NaN
# 97            LeukemiaCancer     ...                NaN            NaN
# 98               LiverCancer     ...                NaN            NaN
# 99                LungCancer     ...                NaN            NaN
# 100                 Lymphoma     ...                NaN            NaN
# 101                 Melanoma     ...                NaN            NaN
# 102              MouthCancer     ...                NaN            NaN
# 103      NervousSystemCancer     ...                NaN            NaN
# 104            OvarianCancer     ...                NaN            NaN
# 105         PancreaticCancer     ...                NaN            NaN
# 107             RectalCancer     ...                NaN            NaN
# 108          SkinCancerOther     ...                NaN            NaN
# 109          SkinCancerOther     ...                NaN            NaN
# 110             TissueCancer     ...                NaN            NaN
# 111            StomachCancer     ...                NaN            NaN
# 134               HepatitisB     ...                NaN            NaN
# 135               HepatitisC     ...                NaN            NaN
# 141              Retinopathy     ...                NaN            NaN
# 142               Tonsilitis     ...                NaN            NaN
# 143               Concussion     ...                NaN            NaN
# 144               BrokenFace     ...                NaN            NaN
# 145           SinusInfection     ...                NaN            NaN
#
#      DrugName   DrugCategory Notes DiseaseCategory_y TreatmentCode    Cost  \
# 0         NaN            NaN   NaN             Joint          006O   795.0
# 1         NaN            NaN   NaN             Joint          006O   795.0
# 2         NaN            NaN   NaN             Joint          006O   795.0
# 10        NaN            NaN   NaN               NaN          7801   393.0
# 11        NaN            NaN   NaN               NaN          7801   393.0
# 12        NaN            NaN   NaN      BoneFracture         NDJ60  1361.0
# 13        NaN            NaN   NaN      BoneFracture         NAJ32  6603.0
# 16        NaN            NaN   NaN      BoneFracture         NDJ42  1712.0
# 17        NaN            NaN   NaN      BoneFracture         NDJ42  1712.0
# 18        NaN            NaN   NaN      BoneFracture         NDJ42  1712.0
# 19        NaN            NaN   NaN      BoneFracture         NDJ42  1712.0
# 20        NaN            NaN   NaN      BoneFracture         NDJ42  1712.0
# 21        NaN            NaN   NaN      BoneFracture         NDJ42  1712.0
# 22        NaN            NaN   NaN      BoneFracture         NDJ42  1712.0
# 23        NaN            NaN   NaN      BoneFracture         NDJ42  1712.0
# 24        NaN            NaN   NaN      BoneFracture         NDJ42  1712.0
# 25        NaN            NaN   NaN               STD          7401   110.0
# 26        NaN            NaN   NaN               STD          7401   110.0
# 27        NaN            NaN   NaN               STD          7401   110.0
# 28        NaN            NaN   NaN               STD          7401   110.0
# 29        NaN            NaN   NaN               STD          7401   110.0
# 30        NaN            NaN   NaN       Circulatory          7801   393.0
# 31        NaN            NaN   NaN       Circulatory          7801   393.0
# 32        NaN            NaN   NaN       Circulatory          7801   393.0
# 33        NaN            NaN   NaN       Circulatory          7801   393.0
# 34        NaN  BloodPressure   NaN       Circulatory          7801   393.0
# 35        NaN            NaN   NaN       Circulatory          7801   393.0
# 36        NaN            NaN   NaN       Circulatory          7801   393.0
# 37        NaN    Cholesterol   NaN       Circulatory          7801   393.0
# 38        NaN            NaN   NaN             Nasal             0     0.0
# ..        ...            ...   ...               ...           ...     ...
# 87        NaN            NaN   NaN            Cancer         AAB00  4346.0
# 88        NaN            NaN   NaN            Cancer          XXX1  4000.0
# 89        NaN            NaN   NaN            Cancer          XXX1  4000.0
# 90        NaN            NaN   NaN            Cancer           274  3952.0
# 91        NaN            NaN   NaN            Cancer         LCD00  3529.0
# 92        NaN            NaN   NaN            Cancer         JFH96  2712.0
# 94        NaN            NaN   NaN            Cancer           494  2958.0
# 95        NaN            NaN   NaN            Cancer         BCA30  2825.0
# 96        NaN            NaN   NaN            Cancer    DQB10ZXD30  2093.0
# 97        NaN            NaN   NaN            Cancer          404F  4096.0
# 98        NaN            NaN   NaN            Cancer         JJA43  4781.0
# 99        NaN            NaN   NaN            Cancer         GDA20  3476.0
# 100       NaN            NaN   NaN            Cancer          404F  4096.0
# 101       NaN            NaN   NaN            Cancer         QDE10  1766.0
# 102       NaN            NaN   NaN            Cancer    EJB10ZXC10  1598.0
# 103       NaN            NaN   NaN            Cancer          011F  2282.0
# 104       NaN            NaN   NaN            Cancer         LAC00  2869.0
# 105       NaN            NaN   NaN            Cancer          192O  1467.0
# 107       NaN            NaN   NaN            Cancer         JFH96  2712.0
# 108       NaN            NaN   NaN            Cancer         QDE10  1766.0
# 109       NaN            NaN   NaN            Cancer         QDE10  1766.0
# 110       NaN            NaN   NaN            Cancer          227O  1516.0
# 111       NaN            NaN   NaN            Cancer         JDA63  2623.0
# 134       NaN            NaN   NaN             Liver          7801   393.0
# 135       NaN            NaN   NaN             Liver          907O   761.0
# 141       NaN            NaN   NaN            Vision          039P  1044.0
# 142       NaN            NaN   NaN            Throat          060N  1829.0
# 143       NaN            NaN   NaN             Brain          901P   319.0
# 144       NaN            NaN   NaN        BrokenBone          055P  1452.0
# 145       NaN            NaN   NaN           Sinuses          7401   110.0
#
#                                                   info  Unnamed: 5
# 0                                Carpal tunnel surgery         NaN
# 1                                Carpal tunnel surgery         NaN
# 2                                Carpal tunnel surgery         NaN
# 10        Specialist consultation same as in blindness         NaN
# 11   Specialist consultation ( There might be no tr...         NaN
# 12                         Screwing of fractured wrist         NaN
# 13                   Lumbar vertebrae fracture surgery         NaN
# 16   Repositioning and binding of bones in arm or h...         NaN
# 17   Repositioning and binding of bones in arm or h...         NaN
# 18   Repositioning and binding of bones in arm or h...         NaN
# 19   Repositioning and binding of bones in arm or h...         NaN
# 20   Repositioning and binding of bones in arm or h...         NaN
# 21   Repositioning and binding of bones in arm or h...         NaN
# 22   Repositioning and binding of bones in arm or h...         NaN
# 23   Repositioning and binding of bones in arm or h...         NaN
# 24   Repositioning and binding of bones in arm or h...         NaN
# 25             basic hospital visit. some random drugs         NaN
# 26                          Dont think theres any cure         NaN
# 27                                         antibiotics         NaN
# 28                   basic hospital visit. Antibiotics         NaN
# 29                                     No special cure         NaN
# 30                                        Life choices         NaN
# 31                                        Life choices         NaN
# 32                                        Life choices         NaN
# 33                                        Life choices         NaN
# 34                                        Life choices         NaN
# 35                                            Medicine         NaN
# 36                                            Medicine         NaN
# 37                                            Medicine         NaN
# 38                                      Nothing needed         NaN
# ..                                                 ...         ...
# 87                      Surgery to remove brain cancer         NaN
# 88                                    Cancer treatment         NaN
# 89                                    Cancer treatment         NaN
# 90                          Breast cancer, complicated         NaN
# 91                                   Removal of Cervix         NaN
# 92   Other removal of colon. (cost depends on how m...         NaN
# 94                              Removal of gallbladder         NaN
# 95                                      Kidney removal         NaN
# 96                                             surgery         NaN
# 97                                                 NaN         NaN
# 98               "Destruction of liver transformation"         NaN
# 99                   Removal of transformaton in lungs         NaN
# 100                                                NaN         NaN
# 101           Removal of transformation in skin tissue         NaN
# 102                      Removal of cancer from tongue         NaN
# 103              Removal of cancer from nervous system         NaN
# 104                                 Removal of ovaries         NaN
# 105                                Surgery in pancreas         NaN
# 107                                                NaN         NaN
# 108           Removal of transformation in skin tissue         NaN
# 109           Removal of transformation in skin tissue         NaN
# 110                                     Tissue surgery         NaN
# 111               Removal of transformation in stomach         NaN
# 134                                     Some medicine          NaN
# 135  "Cure is expensive" but cant find any costs. I...         NaN
# 141                                        eye surgery         NaN
# 142                       Surgery (removal of tonsils)         NaN
# 143  Diagnosis of head, neck and central nervous sy...         NaN
# 144  Surgery on face (nose, mouth, ear or else, sho...         NaN
# 145         Ear, nose and throatdisease hospital visit         NaN
#
# [102 rows x 22 columns]

# %%
len(set(merged['DiseaseName_char']))
# Out:
# 63

# %%
set(merged['Variable Name'])
# Out:
# {'AGQ030',
#  'BPD035',
#  'BPQ020',
#  'BPQ030',
#  'BPQ040A',
#  'BPQ050A',
#  'BPQ080',
#  'BPQ090D',
#  'BPQ100D',
#  'CSQ220',
#  'CSQ240',
#  'CSQ250',
#  'CSQ260',
#  'DIQ080',
#  'DLQ010',
#  'DLQ020',
#  'HEQ010',
#  'HEQ030',
#  'MCD093',
#  'MCQ010',
#  'MCQ025',
#  'MCQ035',
#  'MCQ040',
#  'MCQ050',
#  'MCQ053',
#  'MCQ080',
#  'MCQ080E',
#  'MCQ082',
#  'MCQ092',
#  'MCQ160a',
#  'MCQ160b',
#  'MCQ160c',
#  'MCQ160d',
#  'MCQ160e',
#  'MCQ160f',
#  'MCQ160k',
#  'MCQ160n',
#  'MCQ170k',
#  'MCQ180a',
#  'MCQ180b',
#  'MCQ180c',
#  'MCQ180d',
#  'MCQ180e',
#  'MCQ180f',
#  'MCQ180k',
#  'MCQ180n',
#  'MCQ195',
#  'MCQ203',
#  'MCQ206',
#  'MCQ220',
#  'MCQ230a',
#  'MCQ230b',
#  'MCQ230c',
#  'MCQ230d',
#  'MCQ240a',
#  'MCQ240aa',
#  'MCQ240b',
#  'MCQ240bb',
#  'MCQ240c',
#  'MCQ240cc',
#  'MCQ240d',
#  'MCQ240dd',
#  'MCQ240dk',
#  'MCQ240e',
#  'MCQ240f',
#  'MCQ240g',
#  'MCQ240i',
#  'MCQ240j',
#  'MCQ240k',
#  'MCQ240l',
#  'MCQ240m',
#  'MCQ240n',
#  'MCQ240o',
#  'MCQ240p',
#  'MCQ240q',
#  'MCQ240r',
#  'MCQ240s',
#  'MCQ240t',
#  'MCQ240v',
#  'MCQ240w',
#  'MCQ240x',
#  'MCQ240y',
#  'MCQ240z',
#  'MGD050',
#  'MGQ080',
#  'MGQ110',
#  'OSQ010b',
#  'OSQ010c',
#  'OSQ080',
#  'OSQ120a',
#  'OSQ120b',
#  'OSQ120c',
#  'OSQ120d',
#  'OSQ120e',
#  'OSQ120f',
#  'OSQ120g',
#  'OSQ120h',
#  'SXQ260',
#  'SXQ265',
#  'SXQ270',
#  'SXQ272',
#  'SXQ753'}

# %%
set(costs['DiseaseName_char']) - set(merged['DiseaseName_char'])
# Out:
# {'Bronchitis',
#  'Dental Care',
#  'Diabetes',
#  'EsophagealCancer',
#  'FracturedHip',
#  'GeneralProblem',
#  'LiverCondtion',
#  'Memory',
#  'MentalDisorder',
#  'MovementDisorder',
#  'Osteoporosis',
#  'ProstateCancer',
#  'Psoriasis',
#  'ThyroidCondition'}

# %%
question_id_and_disease = pd.read_csv("data/DiseaseIndicators.csv")

# %%
len(set(question_id_and_disease['DiseaseName_char']))
# Out:
# 84

# %%
set(question_id_and_disease['DiseaseName_char']) - set(costs['DiseaseName_char'])
# Out:
# {'ChronicObstructivePulmonaryDisease',
#  'Emphysema',
#  'FootSores',
#  'FractureHip',
#  'GenericProblem',
#  'HipFracture',
#  'LiverCondition',
#  'MentalHealth',
#  'Post-Natal Care',
#  'WristFracture',
#  nan}
