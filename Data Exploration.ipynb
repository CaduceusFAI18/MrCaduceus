# %%
import pandas as pd
from os import listdir
import numpy as np
from functools import reduce
import math
import re
import pickle

# %%
pickle_in = open("data/preprocessed/removed_nan/mergedX.pkl","rb")
example_dict = pickle.load(pickle_in)

# %%
example_dict
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# ~/py35/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/py35/lib/python3.5/site-packages/pandas/core/frame.py in _repr_html_(self)
#     667
#     668             return self.to_html(max_rows=max_rows, max_cols=max_cols,
# --> 669                                 show_dimensions=show_dimensions, notebook=True)
#     670         else:
#     671             return None
#
# ...

# %%
df_X = pd.read_csv("data/preprocessed/X.csv")
df_Y = pd.read_csv("data/preprocessed/Y.csv")
df_Y = df_Y.drop(['Unnamed: 0'], axis = 1)
# Out:
# /Users/hitchhiker/py35/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (13,14,2496) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(len(df_X))
print(len(df_Y))
# Out:
# 10175
# 10175

# %%
df.sum(axis = 0)
# Out:
# SEQN                                  800202700.0
# LungCancer                                   21.0
# Retinopathy                                 156.0
# LarynxCancer                                  4.0
# KidneyCancer                                 12.0
# HeartFailure                                182.0
# Jaundice                                    157.0
# ChronicBronchitis                           320.0
# SkinCancerOther                             161.0
# EsophagealCancer                              2.0
# CervicalCancer                               37.0
# Blindness                                   432.0
# MentalDisorder                             1247.0
# HPV                                         160.0
# GallbladderCancer                             0.0
# Carpal_Tunnel_Arthritis                       0.0
# StomachCancer                                 3.0
# BrokenFace                                  538.0
# ChronicObstructivePulmonaryDisease          192.0
# ...

# %%
# Out:
# SEQN                                  800202700.0
# LungCancer                                   21.0
# Retinopathy                                 156.0
# LarynxCancer                                  4.0
# KidneyCancer                                 12.0
# HeartFailure                                182.0
# Jaundice                                    157.0
# ChronicBronchitis                           320.0
# SkinCancerOther                             161.0
# EsophagealCancer                              2.0
# CervicalCancer                               37.0
# Blindness                                   432.0
# MentalDisorder                             1247.0
# HPV                                         160.0
# GallbladderCancer                             0.0
# Carpal_Tunnel_Arthritis                       0.0
# StomachCancer                                 3.0
# BrokenFace                                  538.0
# ChronicObstructivePulmonaryDisease          192.0
# ...
